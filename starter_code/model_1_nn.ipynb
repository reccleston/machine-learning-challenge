# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.tar.gz (1.1 kB)
# Requirement already satisfied, skipping upgrade: scikit-learn in /Users/ryaneccleston-murdock/opt/anaconda3/lib/python3.8/site-packages (from sklearn) (0.23.1)
# Requirement already satisfied, skipping upgrade: threadpoolctl>=2.0.0 in /Users/ryaneccleston-murdock/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied, skipping upgrade: scipy>=0.19.1 in /Users/ryaneccleston-murdock/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.5.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /Users/ryaneccleston-murdock/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /Users/ryaneccleston-murdock/opt/anaconda3/lib/python3.8/site-packages (from scikit-learn->sklearn) (0.16.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=249bc8c6f3e8cd5ff7c060c8b91bce7e0478cf0bda7672b0f41358e1e9016f1b
#   Stored in directory: /Users/ryaneccleston-murdock/Library/Caches/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib
# Out:
# Requirement already satisfied: joblib in /Users/ryaneccleston-murdock/opt/anaconda3/lib/python3.8/site-packages (0.16.0)

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.

selected_features = df[df.columns[1:]]
selected_features.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(selected_features, df.koi_disposition)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 3858              1              0              1              1  161.253747
# 63                0              0              0              0    2.539183
# 1680              0              0              0              0    6.383159
# 4637              0              0              0              0  339.633833
# 1764              0              1              1              0   21.391012
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 3858         0.003483        -0.003483   189.093900          0.017600
# 63           0.000005        -0.000005   169.674940          0.001600
# 1680         0.000006        -0.000006   170.604622          0.000744
# 4637         0.008837        -0.008837   260.955200          0.016300
# 1764         0.000117        -0.000117   141.297640          0.004550
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 3858         -0.017600  ...            -182      4.573           0.040
# 63           -0.001600  ...             -74      4.350           0.126
# 1680         -0.000744  ...             -82      4.681           0.039
# 4637         -0.016300  ...            -167      4.522           0.033
# 1764         -0.004550  ...            -131      4.637           0.031
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 3858          -0.160     0.803          0.201         -0.067  298.94003
# 63            -0.103     1.062          0.154         -0.140  291.43997
# 1680          -0.015     0.576          0.022         -0.036  285.57434
# 4637          -0.302     0.901          0.382         -0.074  286.80566
# 1764          -0.058     0.686          0.074         -0.056  290.28503
#
#             dec  koi_kepmag
# 3858  40.419441      15.397
# 63    37.905659      15.026
# 1680  49.962269      15.254
# 4637  44.639870      14.699
# 1764  40.689362      14.985
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# One-hot encode koi_disposition
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

# Label encoding
label_encoder = LabelEncoder().fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# One-hot
y_train_cat = to_categorical(encoded_y_train)
y_test_cat = to_categorical(encoded_y_test)

# %% [markdown]
# # Train the Model

# %%
len(X_train.columns)
# Out:
# 40

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

dim = len(X_train.columns)
num_outcomes = len(y_train_cat[0])

model = Sequential()
model.add(Dense(units=3 * dim, activation='relu', input_dim=dim))
model.add(Dense(units=3 * dim, activation='relu'))
model.add(Dense(units=num_outcomes, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 120)               4920
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               14520
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 363
# =================================================================
# Total params: 19,803
# Trainable params: 19,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Train 
model.fit(
    X_train_scaled,
    y_train_cat,
    epochs=100,
    shuffle=True,
    verbose=0
);
# Out:
# Epoch 1/100
# 164/164 [==============================] - 1s 1ms/step - loss: 0.7073 - accuracy: 0.6414
# Epoch 2/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3670 - accuracy: 0.8027
# Epoch 3/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3592 - accuracy: 0.8074
# Epoch 4/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3517 - accuracy: 0.8206
# Epoch 5/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3392 - accuracy: 0.8353
# Epoch 6/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3374 - accuracy: 0.8322
# Epoch 7/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3274 - accuracy: 0.8415
# Epoch 8/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3149 - accuracy: 0.8588
# Epoch 9/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3353 - accuracy: 0.8384
# Epoch 10/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.3178 - accuracy: 0.8494
# Epoch 11/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.3091 - accuracy: 0.8626
# Epoch 12/100
# 164/164 [==============================] - 0s 3ms/step - loss: 0.3083 - accuracy: 0.8621
# Epoch 13/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.3117 - accuracy: 0.8576
# Epoch 14/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2997 - accuracy: 0.8722
# Epoch 15/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.3118 - accuracy: 0.8615
# Epoch 16/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2766 - accuracy: 0.8807
# Epoch 17/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2896 - accuracy: 0.8734
# Epoch 18/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2780 - accuracy: 0.8776
# Epoch 19/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2760 - accuracy: 0.8820
# Epoch 20/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2685 - accuracy: 0.8806
# Epoch 21/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2893 - accuracy: 0.8751
# Epoch 22/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2908 - accuracy: 0.8693
# Epoch 23/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2781 - accuracy: 0.8724
# Epoch 24/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2687 - accuracy: 0.8867: 0s - loss: 0.2415 - accuracy
# Epoch 25/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2604 - accuracy: 0.8878
# Epoch 26/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2805 - accuracy: 0.8725
# Epoch 27/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2823 - accuracy: 0.8721
# Epoch 28/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2911 - accuracy: 0.8755
# Epoch 29/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2680 - accuracy: 0.8856
# Epoch 30/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2663 - accuracy: 0.8823
# Epoch 31/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.8830
# Epoch 32/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2754 - accuracy: 0.8758
# Epoch 33/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2577 - accuracy: 0.8943
# Epoch 34/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2669 - accuracy: 0.8821
# Epoch 35/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.8832
# Epoch 36/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2518 - accuracy: 0.8880
# Epoch 37/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2589 - accuracy: 0.8885
# Epoch 38/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2858 - accuracy: 0.8690
# Epoch 39/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.8912: 0s - loss: 0.2574 - accura
# Epoch 40/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2435 - accuracy: 0.8969
# Epoch 41/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2560 - accuracy: 0.8888
# Epoch 42/100
# 164/164 [==============================] - 0s 3ms/step - loss: 0.2501 - accuracy: 0.8866
# Epoch 43/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2529 - accuracy: 0.8872
# Epoch 44/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2417 - accuracy: 0.8938
# Epoch 45/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2512 - accuracy: 0.8867
# Epoch 46/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2531 - accuracy: 0.8907
# Epoch 47/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2611 - accuracy: 0.8879
# Epoch 48/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2578 - accuracy: 0.8857
# Epoch 49/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2449 - accuracy: 0.8954
# Epoch 50/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2404 - accuracy: 0.8911
# Epoch 51/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2378 - accuracy: 0.8998
# Epoch 52/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2435 - accuracy: 0.8980
# Epoch 53/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2436 - accuracy: 0.8985
# Epoch 54/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2334 - accuracy: 0.9039
# Epoch 55/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2303 - accuracy: 0.9031
# Epoch 56/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2334 - accuracy: 0.8978
# Epoch 57/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2393 - accuracy: 0.8927
# Epoch 58/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2341 - accuracy: 0.9003
# Epoch 59/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2407 - accuracy: 0.8925
# Epoch 60/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2284 - accuracy: 0.9024
# Epoch 61/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2274 - accuracy: 0.9034
# Epoch 62/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2464 - accuracy: 0.8927
# Epoch 63/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2254 - accuracy: 0.9053
# Epoch 64/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2190 - accuracy: 0.9071
# Epoch 65/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2277 - accuracy: 0.9003
# Epoch 66/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2319 - accuracy: 0.8916
# Epoch 67/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2152 - accuracy: 0.9073
# Epoch 68/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2332 - accuracy: 0.9035
# Epoch 69/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2259 - accuracy: 0.9016
# Epoch 70/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2278 - accuracy: 0.8971
# Epoch 71/100
# 164/164 [==============================] - 0s 2ms/step - loss: 0.2372 - accuracy: 0.8948
# Epoch 72/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2389 - accuracy: 0.8966
# Epoch 73/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2305 - accuracy: 0.9038
# Epoch 74/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2364 - accuracy: 0.8969
# Epoch 75/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2196 - accuracy: 0.9034
# Epoch 76/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2378 - accuracy: 0.8926
# Epoch 77/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2238 - accuracy: 0.9064
# Epoch 78/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2308 - accuracy: 0.8952
# Epoch 79/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2280 - accuracy: 0.9019
# Epoch 80/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2176 - accuracy: 0.9010
# Epoch 81/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2162 - accuracy: 0.9053
# Epoch 82/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2273 - accuracy: 0.8996
# Epoch 83/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2134 - accuracy: 0.9058
# Epoch 84/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2170 - accuracy: 0.9056
# Epoch 85/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2285 - accuracy: 0.8965
# Epoch 86/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2254 - accuracy: 0.9011
# Epoch 87/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2107 - accuracy: 0.9050
# Epoch 88/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2148 - accuracy: 0.9064
# Epoch 89/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2103 - accuracy: 0.9014
# Epoch 90/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2253 - accuracy: 0.8997
# Epoch 91/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2256 - accuracy: 0.9016
# Epoch 92/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2051 - accuracy: 0.9134
# Epoch 93/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2006 - accuracy: 0.9109
# Epoch 94/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2102 - accuracy: 0.9058
# Epoch 95/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2145 - accuracy: 0.9012
# Epoch 96/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2119 - accuracy: 0.9096
# Epoch 97/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2112 - accuracy: 0.9060
# Epoch 98/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2171 - accuracy: 0.9101
# Epoch 99/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2307 - accuracy: 0.8914
# Epoch 100/100
# 164/164 [==============================] - 0s 1ms/step - loss: 0.2165 - accuracy: 0.9095

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_cat, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2593 - accuracy: 0.8919
# Normal Neural Network - Loss: 0.25933873653411865, Accuracy: 0.8918764591217041

# %% [markdown]
# # Save the Model

# %%
model.save('eccleston_nn.h5')
